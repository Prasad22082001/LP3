# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn import preprocessing

# %%
 df=pd.read_csv('diabetes.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.corr().style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_208c7_row0_col0, #T_208c7_row1_col1, #T_208c7_row2_col2, #T_208c7_row3_col3, #T_208c7_row4_col4, #T_208c7_row5_col5, #T_208c7_row6_col6, #T_208c7_row7_col7, #T_208c7_row8_col8 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_208c7_row0_col1 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_208c7_row0_col2 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_208c7_row0_col3, #T_208c7_row7_col4 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_208c7_row0_col4, #T_208c7_row0_col5, #T_208c7_row0_col6, #T_208c7_row2_col8, #T_208c7_row3_col0, #T_208c7_row3_col1, #T_208c7_row3_col7, #T_208c7_row6_col2, #T_208c7_row7_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_208c7_row0_col7 {
#   background-color: #4bb382;
#   color: #f1f1f1;
# }
# #T_208c7_row0_col8, #T_208c7_row1_col6 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_208c7_row1_col0, #T_208c7_row8_col4 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_208c7_row1_col2, #T_208c7_row6_col8 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_208c7_row1_col3 {
#   background-color: #dff3f5;
#   color: #000000;
# }
# #T_208c7_row1_col4 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_208c7_row1_col5, #T_208c7_row3_col6, #T_208c7_row4_col6 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_208c7_row1_col7 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_208c7_row1_col8 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_208c7_row2_col0, #T_208c7_row7_col2 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_208c7_row2_col1 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_208c7_row2_col3 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_208c7_row2_col4 {
#   background-color: #e0f3f5;
#   color: #000000;
# }
# #T_208c7_row2_col5, #T_208c7_row6_col3 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_208c7_row2_col6, #T_208c7_row4_col8 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_208c7_row2_col7 {
#   background-color: #b0e1d6;
#   color: #000000;
# }
# #T_208c7_row3_col2, #T_208c7_row5_col1 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_208c7_row3_col4 {
#   background-color: #70c6ac;
#   color: #000000;
# }
# #T_208c7_row3_col5 {
#   background-color: #97d7c7;
#   color: #000000;
# }
# #T_208c7_row3_col8, #T_208c7_row4_col0 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_208c7_row4_col1 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_208c7_row4_col2 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_208c7_row4_col3 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_208c7_row4_col5 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_208c7_row4_col7, #T_208c7_row7_col6 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_208c7_row5_col0 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_208c7_row5_col2, #T_208c7_row5_col4 {
#   background-color: #ccece6;
#   color: #000000;
# }
# #T_208c7_row5_col3 {
#   background-color: #78cab1;
#   color: #000000;
# }
# #T_208c7_row5_col6, #T_208c7_row8_col3 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_208c7_row5_col7 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_208c7_row5_col8 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_208c7_row6_col0 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_208c7_row6_col1 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_208c7_row6_col4 {
#   background-color: #ceede8;
#   color: #000000;
# }
# #T_208c7_row6_col5 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_208c7_row6_col7 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_208c7_row7_col0 {
#   background-color: #4eb586;
#   color: #f1f1f1;
# }
# #T_208c7_row7_col1 {
#   background-color: #d3eeeb;
#   color: #000000;
# }
# #T_208c7_row7_col5 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_208c7_row7_col8 {
#   background-color: #d9f1f0;
#   color: #000000;
# }
# #T_208c7_row8_col0, #T_208c7_row8_col5 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_208c7_row8_col1 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_208c7_row8_col2 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_208c7_row8_col6 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_208c7_row8_col7 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# </style>
# <table id="T_208c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_208c7_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_208c7_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_208c7_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_208c7_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_208c7_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_208c7_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_208c7_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_208c7_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_208c7_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_208c7_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_208c7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_208c7_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_208c7_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_208c7_row0_col3" class="data row0 col3" >-0.081672</td>
#       <td id="T_208c7_row0_col4" class="data row0 col4" >-0.073535</td>
#       <td id="T_208c7_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_208c7_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_208c7_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_208c7_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_208c7_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_208c7_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_208c7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_208c7_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_208c7_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_208c7_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_208c7_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_208c7_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_208c7_row1_col7" class="data row1 col7" >0.263514</td>
#       <td id="T_208c7_row1_col8" class="data row1 col8" >0.466581</td>
#     </tr>
#     <tr>
#       <th id="T_208c7_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_208c7_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_208c7_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_208c7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_208c7_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_208c7_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_208c7_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_208c7_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_208c7_row2_col7" class="data row2 col7" >0.239528</td>
#       <td id="T_208c7_row2_col8" class="data row2 col8" >0.065068</td>
#     </tr>
#     <tr>
#       <th id="T_208c7_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_208c7_row3_col0" class="data row3 col0" >-0.081672</td>
#       <td id="T_208c7_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_208c7_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_208c7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_208c7_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_208c7_row3_col5" class="data row3 col5" >0.392573</td>
#       <td id="T_208c7_row3_col6" class="data row3 col6" >0.183928</td>
#       <td id="T_208c7_row3_col7" class="data row3 col7" >-0.113970</td>
#       <td id="T_208c7_row3_col8" class="data row3 col8" >0.074752</td>
#     </tr>

# %%
df.drop(['BloodPressure', 'SkinThickness'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose     Insulin         BMI  \
# count   768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   79.799479   31.992578
# std       3.369578   31.972618  115.244002    7.884160
# min       0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000    0.000000   27.300000
# 50%       3.000000  117.000000   30.500000   32.000000
# 75%       6.000000  140.250000  127.250000   36.600000
# max      17.000000  199.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.240885    0.348958
# std                    0.331329   11.760232    0.476951
# min                    0.078000   21.000000    0.000000
# 25%                    0.243750   24.000000    0.000000
# 50%                    0.372500   29.000000    0.000000
# 75%                    0.626250   41.000000    1.000000
# max                    2.420000   81.000000    1.000000

# %%
hist = df.hist(figsize=(20,16))

# %%
X=df.iloc[:, :df.shape[1]-1] #Independent Variables
y=df.iloc[:, -1] #Dependent Variable
X.shape, y.shape
# Out:
# ((768, 6), (768,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def knn(X_train, X_test, y_train, y_test, neighbors, power):
    model = KNeighborsClassifier(n_neighbors=neighbors, p=power)
    
    # Fit and predict on model
    # Model is trained using the train set, and predictions are made based on the test set
    y_pred = model.fit(X_train, y_train).predict(X_test)
    
    print(f"Accuracy for K-Nearest Neighbors model: {accuracy_score(y_test, y_pred)}")
    
    cm = confusion_matrix(y_test, y_pred)
    print(f'''Confusion matrix:
    | Positive Prediction | Negative Prediction
    ---------------+------------------------+----------------------
    Positive Class | True Positive (TP) {cm[0, 0]} | False Negative (FN) {cm[0, 1]}
    ---------------+------------------------+----------------------
    Negative Class | False Positive (FP) {cm[1, 0]} | True Negative (TN) {cm[1, 1]}\n''')
    
    cr = classification_report(y_test, y_pred)
    print('Classification report:\n', cr)

# %%
param_grid = {
 'n_neighbors': range(1, 51),
 'p': range(1, 4)
}
grid = GridSearchCV(estimator=KNeighborsClassifier(), param_grid=param_grid, cv=5)
grid.fit(X_train, y_train)
grid.best_estimator_, grid.best_params_, grid.best_score_
# Out:
# (KNeighborsClassifier(n_neighbors=27),
#  {'n_neighbors': 27, 'p': 2},
#  0.7719845395175262)

# %%
knn(X_train, X_test, y_train, y_test, grid.best_params_['n_neighbors'], grid.best_params_['p'])
# Out:
# Accuracy for K-Nearest Neighbors model: 0.7987012987012987
# Confusion matrix:
#     | Positive Prediction | Negative Prediction
#     ---------------+------------------------+----------------------
#     Positive Class | True Positive (TP) 91 | False Negative (FN) 11
#     ---------------+------------------------+----------------------
#     Negative Class | False Positive (FP) 20 | True Negative (TN) 32
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       102
#            1       0.74      0.62      0.67        52
#
#     accuracy                           0.80       154
#    macro avg       0.78      0.75      0.76       154
# weighted avg       0.79      0.80      0.79       154
